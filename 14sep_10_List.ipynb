# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhay7753/AI_ML_11sep/blob/main/14sep_10_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Recap

# %%
for i in range(5):
  for j in range(6,10):
    print(i,j)
# Out:
# 0 6
# 0 7
# 0 8
# 0 9
# 1 6
# 1 7
# 1 8
# 1 9
# 2 6
# 2 7
# 2 8
# 2 9
# 3 6
# 3 7
# 3 8
# 3 9
# 4 6
# 4 7
# 4 8
# 4 9

# %%
# what is the output
for i in range (2):
  for j in range(2):
    print(j,end=" ")
  print()
# Out:
# 0 1
# 0 1

# %%
for i in range (4):
  for col in range(4):
    print("#",end=" ")
  print()
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for i in range(1,3):
  for j in range (1,3):
    print(i,j,i+j)
  print()
# Out:
# 1 1 2
# 1 2 3
#
# 2 1 3
# 2 2 4

# %% [markdown]
# #List in Python

# %%
m1=90
m2=86
m3=85
m4=83
m5=70

# %%
marks=[90,86,95,83,70]
print(marks)
# Out:
# [90, 86, 95, 83, 70]

# %%
# Difference btw ARRay and list --> array store at a time only one type ,list store multiple datatype this is main difference
a=[45,'Aj',6.8,True]
print(type(a))
# Out:
# <class 'list'>

# %%
student =[]
print(student)
# Out:
# []

# %% [markdown]
# # Indexing

# %%
marks=[90,95,85,96,58]
print(marks[2])
# Out:
# 85

# %%
# Access last index
marks=[90,95,85,96,58]
print(marks[-1])
# Out:
# 58

# %%
print(len(marks))
# Out:
# 5

# %% [markdown]
# Negative indexing

# %%
print(marks[-1])
# Out:
# 58

# %% [markdown]
# #Iterating over a list

# %%
n=len(marks)
print(n)
# Out:
# 5

# %%
print(marks[0])
# Out:
# 90

# %%
for i in range(n):# jb indexing ki jarurat ho tb ise use kre
  print(marks[i])
# Out:
# 90
# 95
# 85
# 96
# 58

# %%
for element in marks:# agar index ka use na ho to ise use kare
  print(element)
# Out:
# 90
# 95
# 85
# 96
# 58

# %%
# Write a code to print even index
for i in range(n):
  if i%2==0:
    print(marks[i])
# Out:
# 90
# 85
# 58

# %%
# Write a code to print all even number
for element in marks:
  if element%2==0:
    print(element)
# Out:
# 90
# 96
# 58

# %% [markdown]
# # Quize

# %%
# what is the output
numbers=[10,20,30]
print(numbers[0])
# Out:
# 10

# %%
# what is the output
print(len(numbers))
# Out:
# 3

# %%
# what is the output
print(numbers[-2])
# Out:
# 20

# %%
# what is the output
fruits=["Apple","orrage","mango"]
fruits[1]="pineapple"
print(fruits)

# %%
# write a code sum of all element in list
marks=[68,70,80,90]

for element in range(len(marks)):
  sum+=marks[element]
print(sum)
# Out:
# 308

# %%
# Write a code to find the average of all the element of marks

print(sum/(len(marks)))
# Out:
# 77.0

# %%
# What is printed
numbers=[9,5,7,1]
print(sorted(numbers))
# Out:
# [1, 5, 7, 9]

# %%
numbers.sort()
print(numbers)
# Out:
# [1, 5, 7, 9]

# %%
# What is the ouptput
names=["A","b","c"]
print(numbers[len(names)-1])
# Out:
# 7

# %%
numbers=[5,10,15]
numbers[1]=numbers[0]+numbers[2]
print(numbers)
# Out:
# [5, 20, 15]

# %%
marks=[50,60,70,80]
for i in range(len(marks)):
  marks[i]=marks[i]+5
print(marks)
# Out:
# [55, 65, 75, 85]

# %%
numbers=[8,2,5,1]
print(min(numbers))
print(max(numbers))
print(max(numbers)-min(numbers))
# Out:
# 1
# 8
# 7

# %%
items=[1,2,3]
for i in range(len(items)):
  items[i]=items[i]*2
print(items)
# Out:
# [2, 4, 6]

# %%
nums=[2,4,6,8]
count=0
for n in nums:
  if n>4:
    count+=1
print(count)
# Out:
# 2

# %%
marks=[80,75,90]
highest=max(marks)
for m in marks:
  print(highest-m)
# Out:
# 10
# 15
# 0

# %%
number=[3,5,7]
result=1
for n in number:
  result*=n
print(result)
# Out:
# 105

# %%
values=[4,8,12]
i=0
while i<len(values):
  print(values[i]//2)
  i+=1
# Out:
# 2
# 4
# 6

# %% [markdown]
# #Homeworks

# %%
numbers=[1,2,3,4]
for i in range(len(numbers)):
  numbers[i]=numbers[i]+1
print(numbers)
# Out:
# [2, 3, 4, 5]

# %%
marks=[65,75,85]
