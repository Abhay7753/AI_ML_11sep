# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhay7753/AI_ML_11sep/blob/main/15sep_dictionary_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Recap -Function

# %%
def show():
  print("Abhayjeet")
print(show())
# Out:
# Abhayjeet
# None

# %%
def show(name,age):
  print("name is",name)
  print("age is",age)

# %%
show(age = 21,name="Abhay jeet")
# Out:
# name is Abhay jeet
# age is 21

# %%
# By default argument
def show(name="Abhay"):
  print(name)

# %%
show()
# Out:
# Abhay

# %% [markdown]
# #Home work question

# %%
def check(num):
  if num%2==0:
    return "Even"
  else:
    return "Odd"

# %%
print(check(8))
# Out:
# Even

# %%
def greet(name):
  print("hello",name)

# %%
greet("abhay")
# Out:
# hello abhay

# %%
def total(numbers):
  s=0
  for n in numbers:
    s+=n
  return s
print(total([5,10,15]))
# Out:
# 30

# %%
def display():
  return "Python"
print(display())
# Out:
# Python

# %%
def largest(a,b):
  if a>b:
    return a
  else :
    return b

print(largest(8,9))
# Out:
# 9

# %% [markdown]
# #Dictionary

# %%
students=["Abhay",22,99.5,"Nagpur"]

# %%
# Dictionary store key value pair
student={
    "name":"Rahul",
    "age":22,
    "cgpa":91.5,
    "city":"nagpur"
}

# %%
print(student)
# Out:
# {'namr': 'Rahul', 'age': 22, 'cgpa': 91.5, 'city': 'nagpur'}

# %%
type(student)
# Out:
# dict

# %%
# In dictionar there are no indeixng accces only by key
student["name"]
# Out:
# 'Rahul'

# %%
student["cgpa"]
student["name"]="Abhay"

# %%
student
# Out:
# {'name': 'Abhay', 'age': 22, 'cgpa': 91.5, 'city': 'nagpur'}

# %%
student["state"]="Uttar pradesh"

# %%
student
# Out:
# {'name': 'Abhay',
#  'age': 22,
#  'cgpa': 91.5,
#  'city': 'nagpur',
#  'state': 'Uttar pradesh'}

# %%
student["Age"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_607/2431116529.py in <cell line: 0>()
# ----> 1 student["Age"]
#
# KeyError: 'Age'

# %%
student.get("Age")# get method error nhi dega rahega to ouptut dega nhi to khali

# %%
student.get("Address","Key not found")
# Out:
# 'Key not found'

# %%
student.get("age","Key not find")
# Out:
# 22

# %%
# Pop
student.get(pop)

# %% [markdown]
# # Loop over Dictionaries

# %%
student
# Out:
# {'name': 'Abhay',
#  'age': 22,
#  'cgpa': 91.5,
#  'city': 'nagpur',
#  'state': 'Uttar pradesh'}

# %%
for k in student.keys():
  print(k)
# Out:
# name
# age
# cgpa
# city
# state

# %%
for k in student.values():
  print(k)
# Out:
# Abhay
# 22
# 91.5
# nagpur
# Uttar pradesh

# %%
for elem in student.items():
  print(elem)
# Out:
# ('name', 'Abhay')
# ('age', 22)
# ('cgpa', 91.5)
# ('city', 'nagpur')
# ('state', 'Uttar pradesh')

# %%
for elem in student.items():
  print("Keys=",elem[0],"value=",elem[1])
# Out:
# Keys= name value= Abhay
# Keys= age value= 22
# Keys= cgpa value= 91.5
# Keys= city value= nagpur
# Keys= state value= Uttar pradesh

# %% [markdown]
# Quiz

# %%
student={
    "name":"abhay",
    "age":22

}

print(student["name"])
# Out:
# abhay

# %%
student={
    "name":"rahul"
}
student["age"]=23
print(student)
# Out:
# {'name': 'rahul', 'age': 23}

# %%
student={
    "name":"ABhay",
    "age":"22"
}

print(len(student))# print number of key value pair
# Out:
# 2

# %%
student={
    "name":"Abhay"

}
print(student.get("city"))# agr hm nin ahget ke print kre to error dega hai agr find nhu huA to
# Out:
# None

# %%
student={
    "NAME":"abhey",
    "age":21
}
print(student.keys())
# Out:
# dict_keys(['NAME', 'age'])

# %%
student={
    "NAME":"abhey",
    "age":21
}
print(student.values())
# Out:
# dict_values(['abhey', 21])

# %%
student={
    "NAME":"abhay",
    "age":21
}
for key in student.keys():
  print(student[key])
# Out:
# abhay
# 21

# %%
student={
    "NAME":"abhay",
    "age":21
}
student.pop("age")
print(student)
# Out:
# {'NAME': 'abhay'}

# %%
cart={
    "MIlk":2,
    "bread":1
}
cart["eggs"]=12
print(len(cart))
# Out:
# 3

# %%
employe={
    "salary":5000
}
employe["salary"]+=10000
print(employe["salary"])
# Out:
# 15000

# %%
student={
    "NAME":"abhay",
    "age":21

}
count=0
for key in student.keys():
  count+=1
print(count)
# Out:
# 2

# %%
student={
    "NAME":"abhay",
    "age":21
}
student["age"]+=12
print(student)
# Out:
# {'NAME': 'abhay', 'age': 33}

# %%
# PRint all employe sallary increnent in each

employe={
    "salary":55000
}
employe["salary"]*=24
print(employe["salary"])
# Out:
# 1320000
