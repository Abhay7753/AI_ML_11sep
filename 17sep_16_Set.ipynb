# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhay7753/AI_ML_11sep/blob/main/17sep_16_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DPP solution

# %%
def fun(values):
  total=0
  for v in values:
    if v%2==0:
      total+=v
  return total
numbers=[5,8,12,7,10]
print(fun(numbers))
# Out:
# 30

# %%
student ={
    "Maths":80,
    "science":90,
    "english":85
}
count=0
for subject in student:
  if student[subject]>=85:
    count+=1
print(count)
# Out:
# 2

# %%
# Print the subjects where the marsks enscored are atleast 85

student ={
    "Maths":80,
    "science":90,
    "english":85
}

sub=[]
for a in student:
  if student[a]>=85:

   sub.append(a)
print(sub)
# Out:
# ['science', 'english']

# %%
names=["Rshul","abhay","aman","manish"]
answer=""

for name in names:
  if len(name)==4:
    answer+=name[-1]
print(answer)
# Out:
# n

# %%
numbers=(10,15,20,25)
result=()
for n in numbers:
  if n%5==0:
    result+=(n//5,)# tuple hai isliye comma lagana parega ise bhulo mt baar baar
print(result)
# Out:
# (2, 3, 4, 5)

# %%
a=(4)
type(a)
# Out:
# int

# %%
a=(4,)
type(a)
# Out:
# tuple

# %%
numbers=(10,15,20,25)
result=(0)
for n in numbers:
  if n%5==0:
    result+=(n//5)
print(result)
# Out:
# 14

# %%
values={2,4,6,8}
total=0

for n in values:
  total+=n
print(total//len(values))
# Out:
# 5

# %%
type(values)
# Out:
# set

# %%
numbers=[3,6,9]

new=[]
for n in numbers:
  new.append(n*n)
print(max(new))
# Out:
# 81

# %%
student=("Abhay",22,96)

name,age,marks=student
if marks>=95:
  grade="A"
else:
  grade="B"
print(name,grade)
# Out:
# Abhay A

# %%
student=("rahul",22,95)
name,age=student # because pass less than number of student element  hence packing are not possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1923/4098378531.py in <cell line: 0>()
#       1 student=("rahul",22,95)
# ----> 2 name,age=student
#
# ValueError: too many values to unpack (expected 2)

# %%
student=("rahul",22,95)
name,age,marks,grade=student# because more than three parameter
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1923/3933608883.py in <cell line: 0>()
#       1 student=("rahul",22,95)
# ----> 2 name,age,marks,grade=student
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
fruits=["Apple","banana","Mango"]

result=[]


for fruit in fruits:
  if len(fruit)>5:
    result.append(fruit.upper())
print(result)
# Out:
# ['BANANA']

# %%
data={
    "a":5,
    "b":10,
    "c":15
}
total=0
for key in data:
  total+=data[key]
print(total/len(data))
# Out:
# 10.0

# %%
number =[2,4,6,8]

i=0
total=0

while i<len(numbers):
  total+=numbers[i]
  i+=2
print(total)
# Out:
# 12

# %%
text="Mississipi"
count={}

for ch in text:
  if ch not in count:
    count[ch]=1
  else:
    count[ch]+=1
print(count["s"])
# Out:
# 4

# %%
words=["cat","elephant","dog","tiger"]

longest=words[0]

for word in words:
  if len(word)>len(longest):
    longest=word
print(longest)
# Out:
# elephant

# %% [markdown]
# # SET

# %% [markdown]
# # collection of unordered distinict element

# %%
# Write a code to store only unique occurence

students=["Abhay","ankur","Abhayjeet","hiudfkui","Abhay"]

s1=[]

for student in students:
  if student not in s1:
    s1.append(student)
print(s1)
# Out:
# ['Abhay', 'ankur', 'Abhayjeet', 'hiudfkui']

# %% [markdown]
# Set :
# 1. Set store unique values
# 2. Unordered
# 3. Mutable (add or remove element)

# %%
num={ 3,6,8,2,1}
type(num)
# Out:
# set

# %%
fruits={ "Apple","Banana","orange"}
len(fruits)
# Out:
# 3

# %%
num={4,5,7,2,4,8,1}
len(num)
# Out:
# 6

# %%
s={ 4,"Abhay",False}
type(s)
# Out:
# set

# %%
l=[] # empty list
t=()# empty tuple

d={}# empty dictionary
s=set()# empty dictionary

type(s)
# Out:
# set

# %%
for n in num:
  print(n)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8

# %%
num={4,5,7,2,8,1}
num.add(10)
print(num)
# Out:
# {1, 2, 4, 5, 7, 8, 10}

# %%
num.discard(4)
print(num)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1923/507530406.py in <cell line: 0>()
# ----> 1 num.remove(4)
#       2 print(num)
#
# KeyError: 4

# %%
item=num.pop()
print(item)
# Out:
# 1

# %%
print(num)
# Out:
# {2, 5, 7, 8, 10}

# %%
num.clear()

# %%
fruits={"Apple","Orange","Mango"}

"Orange" in fruits
# Out:
# True

# %%
# Union-- |
a={1,2,3}
b={3,4,6}
print(a|b)
# Out:
# {1, 2, 3, 4, 6}

# %%
# Intersection -- &
a={1,2,3}
b={3,4,6}
print(a&b)
# Out:
# {3}

# %%
# Set differene --  (-)
a={1,2,3}
b={3,4,6}
print(a-b)
# Out:
# {1, 2}

# %% [markdown]
# # Quiz  and Practice

# %%
numbers={20,10,30,10,20}

total=0
for n in numbers:
  total+=n
print(total)
# Out:
# 60

# %%
colors={"Red","Green","Blue"}
total=0
for color in colors:
  if "e" in color.lower():
       total+=1

print(total)
# Out:
# 3

# %%
numbers=[10,20,20,30,10]
unique=set(numbers)
print(len(unique))
# Out:
# 3

# %%
fruits ={ "Apple","Banana"}
if "Mango" in fruits:
  print("yes")
else:
  print("No")
# Out:
# No

# %%
text="Banana"

letters=set(text)
print(len(letters))
# Out:
# 3

# %%
a={"Python","SQL"}
b={"Python","Power BI"}
print(a&b)
# Out:
# {'Python'}
