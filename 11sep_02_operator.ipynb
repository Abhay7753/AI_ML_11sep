# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhay7753/AI_ML_11sep/blob/main/11sep_02_operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Operators

# %%
# Arithmetic operators
print(5+4)
# Out:
# 9

# %%
print(4-9)
# Out:
# -5

# %%
print(10*3)
# Out:
# 30

# %%
print(20/5)
# Out:
# 4.0

# %%
# Floored value operator
print(20//6)
# Out:
# 3

# %%
print(10//5)
# Out:
# 2

# %%
print(10/5)
# Out:
# 2.0

# %%
# % modulus operator
print(10%3)
# Out:
# 1

# %%
print(10%6)
# Out:
# 4

# %%
print(10%2)
# Out:
# 0

# %%
# Power operator
print(3**2)
# Out:
# 9

# %%
# Calculator-->
# take two input from user and print the all operations with arithmatic operator
a=int(input())
b=int(input())
print("Addition:",a+b)
print("subtraction",a-b)
print("multi:",a*b)
print("divide floar:",a/b)
print("int value:",a//b)
print("rem:",a%b)
print("power:",a**b)
# Out:
# 8
# 9
# Addition: 17
# subtraction -1
# multi: 72
# divide floar: 0.8888888888888888
# int value: 0
# rem: 8
# power: 134217728

# %%
#Assignment operator
x=10
print(x)
# Out:
# 10

# %%
x=10
x+=10
print(x)
# Out:
# 20

# %%
x=10
x-=6
print(x)
# Out:
# 4

# %% [markdown]
# Camparision operator

# %%
# greater than
10>5
# Out:
# True

# %%
# Not equal to
6!=5
# Out:
# True

# %% [markdown]
# LOGICAL OPERATOR

# %%
# And ,or,not
4>3
# Out:
# True

# %%
(4>3)and(5>2)#And
# Out:
# True

# %%
(4<3)and(5>4)
# Out:
# False

# %%
(4<3)or(5>2)#Or operator(agar 1 bhi conditon true tehn output true)
# Out:
# True

# %%
# not --->toggle(opposite)
# True---> false
# False---> true
not(4>7)
# Out:
# True

# %%
not(4==5)
# Out:
# True

# %%
not(4!=7)
# Out:
# False

# %%
not((3>3)and(6<3))
# Out:
# True

# %%
not((3>3)or(6<3)) # always solve according to brackegt
# Out:
# True

# %% [markdown]
# Membership operator

# %%
"a" in "abhay"# ye find kr rha hai
# Out:
# True

# %%
"z" in "abhay"
# Out:
# False
