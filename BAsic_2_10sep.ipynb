# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhay7753/AI_ML_11sep/blob/main/BAsic_2_10sep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data type **

# %%
type("5,7")
# Out:
# str

# %%
type("true")
# Out:
# str

# %%
type(False)
# Out:
# bool

# %% [markdown]
# #Taking input from user

# %%
name="Abhay jeet"

# %%
#input()
name=input()
# Out:
# abhay jeet

# %%
print(name)
# Out:
# abhay jeet

# %%
name=input("Enter your name:")

# %%
# take two int as input from user ans print their sum
a=int(input("Enter the first digit"))
b=int(input("Enter the second digit"))

print(a+b)
# Out:
# Enter the first digit6
# Enter the second digit6
# 12

# %%
#string concatenation

# %%
4+6
# Out:
# 10

# %%
"4"+"5"
# Out:
# '45'

# %%
# input()---> it is always will store in string by default

# %% [markdown]
# #Type Casting

# %%
age="20"
new_age=int(age)# type casting
type(new_age)
# Out:
# int

# %%
# Take year of birt as input and print the age
a=int(input("Enter the year of birth"))

print(2026-a)
# Out:
# Enter the year of birth2022
# 4

# %%
# take length and breath of rec as input and print its area
a=int(input())
b=int(input())
print(a*b)
# Out:
# 5
# 6
# 30

# %%
# take float because always not l and b value integer
a=float(input())
b=float(input())
print(a*b)
# Out:
# 7.5
# 8.9
# 66.75

# %%
# Take the name,age and height int(inches)
name=input()
age=input()
height=float(input())
print(name,age,height)
# Out:
# abhayjeet
# 18
# 12.5
# abhayjeet 18 12.5
